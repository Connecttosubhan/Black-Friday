# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv(r'SalesFriday.csv')

# %%
dataset
# Out:
#        Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 0           F   10          10              2               0              3
# 1           F   10          10              2               0              1
# 2           F   10          10              2               0             12
# 3           F   10          10              2               0             12
# 4           M   60          16              5               0              8
# 5           M   30          15              3               0              1
# 6           M   48           7              2               1              1
# 7           M   48           7              2               1              1
# 8           M   48           7              2               1              1
# 9           M   30          20              1               1              8
# 10          M   30          20              1               1              5
# 11          M   30          20              1               1              8
# 12          M   30          20              1               1              8
# 13          M   30          20              1               1              1
# 14          F   53           9              1               0              5
# 15          F   53           9              1               0              4
# 16          F   53           9              1               0              2
# 17          F   53           9              1               0              5
# 18          M   40           1              1               1              1
# 19          M   30          12              5               1              1
# 20          M   30          12              5               1              5
# 21          M   30          12              5               1              8
# 22          M   30          12              5               1              8
# 23          M   30          12              5               1              8
# 24          M   30          12              5               1              1
# 25          M   30          17              0               0              6
# 26          M   30          17              0               0              8
# 27          M   30          17              0               0              5
# 28          M   30          17              0               0              5
# 29          F   40           1              5               1              2
# ...       ...  ...         ...            ...             ...            ...
# 537547      M   22          18              1               0              1
# 537548      M   53           1              1               1             15
# 537549      M   53           1              1               1              2
# 537550      M   48           3              3               0              1
# 537551      M   48           3              3               0              5
# 537552      M   48           3              3               0              6
# 537553      M   48           3              3               0             10
# 537554      M   48           3              3               0              5
# 537555      M   48           3              3               0             13
# 537556      M   22          20              1               1              8
# 537557      M   22          20              1               1              2
# 537558      M   22          20              1               1              8
# 537559      M   22          20              1               1              8
# 537560      M   22          20              1               1              8
# 537561      M   22          20              1               1              8
# 537562      M   22          20              1               1              1
# 537563      M   22          20              1               1              8
# 537564      M   22          20              1               1              5
# 537565      M   22          20              1               1              8
# 537566      M   22          20              1               1              5
# 537567      M   22          20              1               1              8
# 537568      M   22          20              1               1             11
# 537569      M   22          20              1               1              5
# 537570      M   22          20              1               1              1
# 537571      M   40          16              1               0              1
# 537572      M   40          16              1               0              1
# 537573      M   40          16              1               0              1
# 537574      M   40          16              1               0              8
# 537575      M   40          16              1               0              5
# 537576      M   40          16              1               0              5
#
#         Purchase  Category
# 0           8370         1
# 1          15200         1
# 2           1422         1
# 3           1057         1
# 4           7969         0
# 5          15227         1
# 6          19215         1
# 7          15854         1
# 8          15686         1
# 9           7871         1
# 10          5254         1
# 11          3957         1
# 12          6073         1
# 13         15665         1
# 14          5378         1
# 15          2079         1
# 16         13055         1
# 17          8851         1
# 18         11788         1
# 19         19614         0
# 20          8584         0
# 21          9872         0
# 22          9743         0
# 23          5982         0
# 24         11927         0
# 25         16662         0
# 26          5887         0
# 27          6973         0
# 28          5391         0
# 29         16352         1
# ...          ...       ...
# 537547     11543         0
# 537548     20924         1
# 537549     13082         1
# 537550     11658         0
# 537551      6863         0
# 537552     16415         0
# 537553     18526         0
# 537554      7099         0
# 537555       578         0
# 537556      2183         1
# 537557     12724         1
# 537558      7796         1
# 537559      7770         1
# 537560      5940         1
# 537561      7834         1
# 537562     11508         1
# 537563      6074         1
# 537564      7084         1
# 537565      7934         1
# 537566      5350         1
# 537567      1994         1
# 537568      5930         1
# 537569      7042         1
# 537570     15491         1
# 537571     11852         0
# 537572     11664         0
# 537573     19196         0
# 537574      8043         0
# 537575      7172         0
# 537576      6875         0
#
# [537577 rows x 8 columns]

# %%
dataset.head()
# Out:
#   Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 0      F   10          10              2               0              3
# 1      F   10          10              2               0              1
# 2      F   10          10              2               0             12
# 3      F   10          10              2               0             12
# 4      M   60          16              5               0              8
#
#    Purchase  Category
# 0      8370         1
# 1     15200         1
# 2      1422         1
# 3      1057         1
# 4      7969         0

# %%
dataset.tail()
# Out:
#        Gender  1ge  Occupation  Stay in Years  Marital Status  Prod_category  \
# 537572      M   40          16              1               0              1
# 537573      M   40          16              1               0              1
# 537574      M   40          16              1               0              8
# 537575      M   40          16              1               0              5
# 537576      M   40          16              1               0              5
#
#         Purchase  Category
# 537572     11664         0
# 537573     19196         0
# 537574      8043         0
# 537575      7172         0
# 537576      6875         0

# %%
dataset.isnull().any()
# Out:
# Gender            False
# 1ge               False
# Occupation        False
# Stay in Years     False
# Marital Status    False
# Prod_category     False
# Purchase          False
# Category          False
# dtype: bool

# %%
x=dataset.iloc[:,0:7].values
x
# Out:
# array([['F', 10, 10, ..., 0, 3, 8370],
#        ['F', 10, 10, ..., 0, 1, 15200],
#        ['F', 10, 10, ..., 0, 12, 1422],
#        ...,
#        ['M', 40, 16, ..., 0, 8, 8043],
#        ['M', 40, 16, ..., 0, 5, 7172],
#        ['M', 40, 16, ..., 0, 5, 6875]], dtype=object)

# %%
y=dataset.iloc[:,-1:].values
y
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int64)

# %%
from sklearn.preprocessing import LabelEncoder
lor=LabelEncoder()

# %%
x[:,0]=lor.fit_transform(x[:,0])
x
# Out:
# array([[0, 10, 10, ..., 0, 3, 8370],
#        [0, 10, 10, ..., 0, 1, 15200],
#        [0, 10, 10, ..., 0, 12, 1422],
#        ...,
#        [1, 40, 16, ..., 0, 8, 8043],
#        [1, 40, 16, ..., 0, 5, 7172],
#        [1, 40, 16, ..., 0, 5, 6875]], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[1, 30, 0, ..., 0, 8, 7837],
#        [1, 30, 2, ..., 0, 5, 8762],
#        [1, 30, 0, ..., 1, 8, 7778],
#        ...,
#        [0, 48, 15, ..., 1, 5, 6991],
#        [1, 22, 4, ..., 1, 2, 13251],
#        [1, 60, 17, ..., 0, 8, 9905]], dtype=object)

# %%
y_train
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [0],
#        [1],
#        [0]], dtype=int64)

# %%
x_test
# Out:
# array([[0, 22, 4, ..., 0, 1, 11394],
#        [1, 30, 20, ..., 1, 7, 12781],
#        [1, 53, 2, ..., 1, 6, 20068],
#        ...,
#        [0, 30, 1, ..., 0, 8, 7957],
#        [1, 30, 14, ..., 0, 5, 8770],
#        [1, 40, 14, ..., 0, 6, 20487]], dtype=object)

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int64)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.transform(x_test)
# Out:
# C:\Users\pandu\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\pandu\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# C:\Users\pandu\Anaconda3\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
x_train
# Out:
# array([[ 0.57015696, -0.38468554, -1.23968144, ..., -0.83107805,
#          0.7225614 , -0.30111344],
#        [ 0.57015696, -0.38468554, -0.93292539, ..., -0.83107805,
#         -0.07724542, -0.11549459],
#        [ 0.57015696, -0.38468554, -1.23968144, ...,  1.20325642,
#          0.7225614 , -0.31295291],
#        ...,
#        [-1.75390301,  1.23668492,  1.06098893, ...,  1.20325642,
#         -0.07724542, -0.47087943],
#        [ 0.57015696, -1.10529463, -0.62616934, ...,  1.20325642,
#         -0.87705224,  0.78530867],
#        [ 0.57015696,  2.31759856,  1.36774498, ..., -0.83107805,
#          0.7225614 ,  0.11387011]])

# %%
x_test
# Out:
# array([[-1.75390301, -1.10529463, -0.62616934, ..., -0.83107805,
#         -1.14365451,  0.41266629],
#        [ 0.57015696, -0.38468554,  1.82787906, ...,  1.20325642,
#          0.45595913,  0.69099423],
#        [ 0.57015696,  1.68706561, -0.93292539, ...,  1.20325642,
#          0.18935685,  2.15326942],
#        ...,
#        [-1.75390301, -0.38468554, -1.08630342, ..., -0.83107805,
#          0.7225614 , -0.27703315],
#        [ 0.57015696, -0.38468554,  0.90761091, ..., -0.83107805,
#         -0.07724542, -0.11388923],
#        [ 0.57015696,  0.51607583,  0.90761091, ..., -0.83107805,
#          0.18935685,  2.23734974]])

# %%
y_test
# Out:
# array([[1],
#        [1],
#        [1],
#        ...,
#        [1],
#        [1],
#        [0]], dtype=int64)

# %%
from sklearn.tree import DecisionTreeClassifier
classifier=DecisionTreeClassifier(criterion="gini",random_state=0)

# %%
classifier.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
y_predict=classifier.predict(x_test)
y_predict
# Out:
# array([1, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_predict)
# Out:
# 0.7338070612746009

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_predict)
cm
# Out:
# array([[19306, 13696],
#        [14924, 59590]], dtype=int64)

# %%
import sklearn.metrics as metrics
fpr,tpr,threshold=metrics.roc_curve(y_test,y_predict)
roc_auc=metrics.auc(fpr,tpr)
roc_auc
# Out:
# 0.6923551692518375

# %%
plt.title("ROC")
plt.plot(fpr,tpr,label="AUC=%0.2f"%roc_auc,color="red")
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.legend()
plt.show()
